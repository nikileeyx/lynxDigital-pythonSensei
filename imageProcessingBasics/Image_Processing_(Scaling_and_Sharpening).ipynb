# %% [markdown]
# #Image Processing Notebook (Sharpening and Scaling)
#
# Image processing is used in multiple applications of enhancement and deconstruction. In this notebook, we will look at image sharpening, scaling and composition.
#
# .
#
#
# **Image Processing Notebook Content**
#
# 1) Understanding the histogram plot
#
# 2) Post-processing the image into its RGB channels
#
# 3) Using kernels to create effects on images

# %%
import numpy as np
import pandas as pd
import cv2 as cv 
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image 
import matplotlib.pylab as plt

# %%
img = cv.imread('image.png')
img = cv.resize(img, (200,200))

hist,bins = np.histogram(img.flatten(),256,[0,256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(hist.max()) / cdf.max()
plt.plot(cdf_normalized, color = 'b')
plt.hist(img.flatten(),256,[0,256], color = 'g')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F0F81FDE550>

# %%
def rgb_splitter(image):
  rgb_list = ["Reds", 'Greens','Blues']
  fig,ax = plt.subplots(1,3,figsize = (17,7), sharey = True)
  for i in range(3):
    ax[i].imshow(image[:,:,i], cmap = rgb_list[i])
    ax[i].set_title(rgb_list[i], fontsize = 22)
    ax[i].axis('off')
  fig.tight_layout()

rgb_splitter(img)

# %% [markdown]
# **Other Resources to Explore!**
#
# RGB Colour Picker: https://www.rapidtables.com/web/color/RGB_Color.html
#
# How to Use Photoshop to Resize and Sharpen Images for the Web: https://digital-photography-school.com/photoshop-sharpen-images-web/
